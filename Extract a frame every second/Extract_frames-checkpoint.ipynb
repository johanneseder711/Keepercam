# %%
import cv2
import matplotlib.pyplot as plt

# %%
# Opens the Video file
cap= cv2.VideoCapture('video.MOV')
# Out:
# OpenCV: Couldn't read video stream from file "video.MOV"
# [ERROR:0@30.921] global /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/videoio/src/cap.cpp (166) open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.5.5) /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_images.cpp:253: error: (-5:Bad argument) CAP_IMAGES: can't find starting number (in the name of file): video.MOV in function 'icvExtractPattern'

# %%
# get the number of frames per second
fps = cap.get(cv2.CAP_PROP_FPS)
print(fps)
# Out:
# 0.0

# %%
# get the total number of frames in the video
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(frame_count)
# Out:
# 0

# %%
duration = frame_count/fps
print("The video takes about %.2f seconds" %(frame_count/fps))
# Out:
# The video takes about 23.98 seconds

# %%
# Capture frame-by-frame
ret, frame = cap.read()

# %%
plt.figure(figsize=(10,7))
plt.imshow(frame)
plt.axis(False)
plt.show()

# %%
# Opens the Video file
cap= cv2.VideoCapture('video.MOV')
i=0
j = 1
while(cap.isOpened()):
    # read the current frame
    ret, frame = cap.read()
    if(i%int(fps) == 0):
        if ret == False:
            break
        cv2.imwrite('frame_at_second_'+str(j)+'.jpg',frame)
        j+=1
    i+=1
 
cap.release()
cv2.destroyAllWindows()
